# %%
from experiments import iterations_view_timing, iterations_view_timing_total
from experiments import iterations_view_utilization
from experiments import iterations_view_placed, iterations_view_sent, iterations_view_returned

from experiments import by_one_iterations_algo

# %%
experiment_path = "./iterative_experiments/5"

# %%
for _ in range(6):
    # %time by_one_iterations_algo(experiment_path)
# эту ячейку можно запускать много раз (итерации метапланировщика)
# Out:
# CPU times: user 3min 25s, sys: 6.19 s, total: 3min 32s
# Wall time: 3min 53s
# CPU times: user 3min 52s, sys: 6.81 s, total: 3min 59s
# Wall time: 4min 21s
# CPU times: user 4min 4s, sys: 7.19 s, total: 4min 11s
# Wall time: 4min 33s
# CPU times: user 4min 28s, sys: 7.89 s, total: 4min 36s
# Wall time: 4min 58s
# CPU times: user 4min 25s, sys: 7.15 s, total: 4min 33s
# Wall time: 4min 55s
# CPU times: user 4min 45s, sys: 8.06 s, total: 4min 53s
# Wall time: 5min 18s

# %% [markdown]
# ## Возвращаемые и размещенные запросы

# %%
# возвращаемые запросы на итерациях
df, ax = iterations_view_returned(experiment_path)
ax
# Out:
# итерация 1
# размещено за итерацию 536
# возвращалось за итерацию 0
# из возвращаемых переназначены 0
# -----
# итерация 2
# размещено за итерацию 536
# возвращалось за итерацию 0
# из возвращаемых переназначены 0
# -----
# итерация 3
# размещено за итерацию 536
# возвращалось за итерацию 0
# из возвращаемых переназначены 0
# -----
# итерация 4
# размещено за итерацию 536
# возвращалось за итерацию 0
# из возвращаемых переназначены 0
# -----
# итерация 5
# размещено за итерацию 536
# возвращалось за итерацию 0
# из возвращаемых переназначены 0
# -----
# итерация 6
# размещено за итерацию 520
# возвращалось за итерацию 0
# из возвращаемых переназначены 0
# -----

# %% [markdown]
# ## Время работы на ЦОД

# %%
df, ax = iterations_view_timing(experiment_path)
ax

# %% [markdown]
# ## Время работы локальных и мета

# %%
iterations_view_timing_total(df)

# %% [markdown]
# ## Размещено запросов

# %%
df, ax = iterations_view_placed(experiment_path)
print("Размещено запросов по итерациям")
print(df.sum(axis=1))
# Out:
# Размещено запросов по итерациям
# 0     711.0
# 1     778.0
# 2     845.0
# 3     912.0
# 4     979.0
# 5    1046.0
# 6    1111.0
# dtype: float64

# %% [markdown]
# ## Утилизация

# %%
df, ax = iterations_view_utilization(experiment_path)
print("Средняя загрузка ресурсов по итерациям")
print(df.mean(axis=1))
# Out:
# Средняя загрузка ресурсов по итерациям
# 0    0.297807
# 1    0.321389
# 2    0.347090
# 3    0.371661
# 4    0.395876
# 5    0.419906
# 6    0.443290
# dtype: float64
