# %%
from experiments import iterations_view_timing, iterations_view_timing_total
from experiments import iterations_view_utilization
from experiments import iterations_view_placed, iterations_view_sent, iterations_view_returned

from experiments import iterations_algo

# %%
experiment_path = "./iterative_experiments/2/dc_loaded/random/"

# %%
for i in range(6):
    # %time iterations_algo(experiment_path)
# эту ячейку можно запускать много раз (итерации метапланировщика)
# Out:
# smth was deleted, new len is 0
# smth was deleted, new len is 0
# dcs proposing taking away: 1
# ACCEPTED
# recursive search for 2 tenants
# CPU times: user 11.1 s, sys: 206 ms, total: 11.3 s
# Wall time: 26.5 s
# smth was deleted, new len is 3
# smth was deleted, new len is 0
# dcs proposing taking away: 1
# ACCEPTED
# recursive search for 3 tenants
# dcs proposing taking away: 1
# ACCEPTED
# recursive search for 1 tenants
# CPU times: user 14.9 s, sys: 307 ms, total: 15.2 s
# Wall time: 27.4 s
# smth was deleted, new len is 1
# dcs proposing taking away: 1
# ACCEPTED
# recursive search for 1 tenants
# dcs proposing taking away: 1
# ACCEPTED
# recursive search for 1 tenants
# CPU times: user 15.9 s, sys: 368 ms, total: 16.2 s
# Wall time: 23.2 s
# dcs proposing taking away: 1
# ACCEPTED
# recursive search for 3 tenants
# CPU times: user 12.7 s, sys: 216 ms, total: 13 s
# Wall time: 14.9 s
# CPU times: user 8.71 s, sys: 152 ms, total: 8.86 s
# Wall time: 9.17 s
# CPU times: user 5.16 s, sys: 104 ms, total: 5.26 s
# Wall time: 5.38 s

# %% [markdown]
# ## Возвращаемые и размещенные запросы

# %%
# возвращаемые запросы на итерациях
df, ax = iterations_view_returned(experiment_path)
ax
# Out:
# итерация 1
# размещено за итерацию 76
# возвращалось за итерацию 2
# из возвращаемых переназначены 2
# -----
# итерация 2
# размещено за итерацию 103
# возвращалось за итерацию 4
# из возвращаемых переназначены 4
# -----
# итерация 3
# размещено за итерацию 90
# возвращалось за итерацию 2
# из возвращаемых переназначены 2
# -----
# итерация 4
# размещено за итерацию 113
# возвращалось за итерацию 3
# из возвращаемых переназначены 3
# -----
# итерация 5
# размещено за итерацию 18
# возвращалось за итерацию 0
# из возвращаемых переназначены 0
# -----
# итерация 6
# размещено за итерацию 0
# возвращалось за итерацию 0
# из возвращаемых переназначены 0
# -----

# %% [markdown]
# ## Время работы на ЦОД

# %%
df, ax = iterations_view_timing(experiment_path)
ax

# %% [markdown]
# ## Время работы локальных и мета

# %%
iterations_view_timing_total(df)

# %% [markdown]
# ## Размещено запросов

# %%
df, ax = iterations_view_placed(experiment_path)
print("Размещено запросов по итерациям")
print(df.sum(axis=1))
# Out:
# Размещено запросов по итерациям
# 0     711.0
# 1     787.0
# 2     890.0
# 3     980.0
# 4    1093.0
# 5    1111.0
# 6    1111.0
# dtype: float64

# %% [markdown]
# ## Утилизация

# %%
df, ax = iterations_view_utilization(experiment_path)
print("Средняя загрузка ресурсов по итерациям")
print(df.mean(axis=1))
# Out:
# Средняя загрузка ресурсов по итерациям
# 0    0.297807
# 1    0.333500
# 2    0.382740
# 3    0.417516
# 4    0.450179
# 5    0.454642
# 6    0.454642
# dtype: float64
